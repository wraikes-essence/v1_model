# %%
# Description: Predictive Model, All Impressions
# Each record is a unique user and campaign combination. Use only the first survey response per user & campaign. 
# And remove all impressions afterwards.  Convert the remaining impressions into separate columns with one cut per column, 
# and the value signifying the frequency.
import configparser
import pandas as pd, numpy as np, datetime, os, sys
from functools import reduce
from google.cloud import bigquery


def df_rename(df):

    df = df.rename(
        columns = {
            'map_systm': 'systm',
            'map_plfh': 'plfh',
            'map_grp': 'group',
            'Answer_desired': 'answer',
            'imp_imp_event_time': 'event_time',
            'map_dcm_placement_id': 'placement_id',
            'map_dcm_ad_id': 'ad_id',
            'imp_table_match_rendering_id': 'rendering_id',
            'map_prst_site': 'site'
        }
    )

    return df

# Only keep users who have answered the first two questions:
def screen_surveys(df):
    grp = df.groupby('user_id').apply(lambda x: 1 if 1 in x.Question.values else 0).reset_index()
    idx = grp[grp[0]==1].user_id.values

    new_df = df[
        (df['user_id'].isin(idx)) &
        (df.Question==0)
    ]
    
    return new_df

# Only keep impressions within 7 days of the first scrutineer survey taken.
def date_filter(df):
    df['date'] = pd.to_datetime(df['date'])
    df['Created'] = pd.to_datetime(df['Created'])
    
    filters = df.sort_values(by=['user_id', 'campaign_id', 'Created'])
    filters = df.groupby(['user_id', 'campaign_id']).first().reset_index()[['user_id', 'campaign_id', 'Created']]
    new_df = pd.merge(df, filters, how='inner', on=['user_id', 'campaign_id', 'Created'])
    
    new_df['recency'] = pd.to_timedelta(new_df['Created'] - new_df['date'])

    new_df = new_df[
        (new_df.recency <= '7 days') & 
        (new_df.recency >= '0 days')
    ]
    
    return new_df

# Create dummy columns for different cuts.
def cuts(df):
    df['cuts'] = df.systm.str.cat([df.plfh, df.site], sep='_')
    df = pd.get_dummies(df, columns=['group'])

    return df

# Create supporting dfs to create a new df filtered by user_id and campaign_id.  
def supporting_dfs(df):
    df_answer = df.groupby(['user_id', 'campaign_id'])['answer'].max().reset_index()
    df_grp = df.groupby(['user_id', 'campaign_id'])[['group_CON', 'group_EXP']].first().reset_index()
    df_freq = df.groupby(['user_id', 'campaign_id'])['frequency'].first().reset_index()

    df_cuts = df.groupby(['user_id', 
                         'campaign_id',
                         'event_time', 
                         'placement_id', 
                         'ad_id', 
                         'rendering_id', 
                         'cuts']).size().reset_index()

    df_cuts = df_cuts.groupby(['user_id', 'campaign_id', 'cuts']).size().unstack().reset_index().fillna(0)

    return [df_answer, df_grp, df_freq, df_cuts]

# Combine supporting dfs to one final df
def combine_dfs(dfs_list):
    df = reduce(lambda left, right: pd.merge(left, right, how='inner', on=['user_id', 'campaign_id']), dfs_list)

    return df

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
config = configparser.ConfigParser()
config.read('..\Resource\liftconfig.ini')
# Out:
# []

# %%
keyFile=outputFile=r'C:\Users\william.raikes\Programming\Python\abacus\mvp_model\essence-analytics-dwh-627924bbda04.json'
client=bigquery.Client.from_service_account_json(keyFile)
job_config = bigquery.QueryJobConfig()
job_config.allow_large_results=True
project = 'essence-analytics-dwh'

# %%
cb_sql = 'SELECT * FROM Project_Abacus_Brand_Lift.Chrome_Final_noMOAT_FullScrutineer_Frequencies_flat_Filtered'
cb_df = client.query(cb_sql).to_dataframe()

# %%
cb_dfx = cb_df.copy()
cb_dfx['date'] = pd.to_datetime(cb_df['date'])
cb_dfx['Created'] = pd.to_datetime(cb_dfx['Created'])
filters = cb_dfx.sort_values(by=['user_id', 'campaign_id', 'Created'])
filters = cb_dfx.groupby(['user_id', 'campaign_id']).first().reset_index()[['user_id', 'campaign_id', 'Created']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d41d0aa788b6> in <module>()
# ----> 1 cb_dfx['date'] = pd.to_datetime(cb_df['date'])
#       2 cb_dfx['Created'] = pd.to_datetime(cb_dfx['Created'])
#       3 filters = cb_dfx.sort_values(by=['user_id', 'campaign_id', 'Created'])
#       4 filters = cb_dfx.groupby(['user_id', 'campaign_id']).first().reset_index()[['user_id', 'campaign_id', 'Created']]
#
# NameError: name 'cb_dfx' is not defined

# %%
pd.merge(cb_df, filters, how='inner', on=['user_id', 'campaign_id', 'Created'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-e00a3788aaa7> in <module>()
# ----> 1 pd.merge(cb_df, filters, how='inner', on=['user_id', 'campaign_id', 'Created'])
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      56                          copy=copy, indicator=indicator,
#      57                          validate=validate)
# ---> 58     return op.get_result()
#      59
#      60
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     580                 self.left, self.right)
#     581
# --> 582         join_index, left_indexer, right_indexer = self._get_join_info()
#     583
#     584         ldata, rdata = self.left._data, self.right._data
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     746         else:
#     747             (left_indexer,
# --> 748              right_indexer) = self._get_join_indexers()
#     749
#     750             if self.right_index:
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     725                                   self.right_join_keys,
#     726                                   sort=self.sort,
# --> 727                                   how=self.how)
#     728
#     729     def _get_join_info(self):
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1048
#    1049     # get left & right join labels and num. of levels at each location
# -> 1050     llab, rlab, shape = map(list, zip(* map(fkeys, left_keys, right_keys)))
#    1051
#    1052     # get flat i8 keys from label lists
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _factorize_keys(lk, rk, sort)
#    1478     rizer = klass(max(len(lk), len(rk)))
#    1479
# -> 1480     llab = rizer.factorize(lk)
#    1481     rlab = rizer.factorize(rk)
#    1482
#
# TypeError: Argument 'values' has incorrect type (expected numpy.ndarray, got Index)

# %%
new_df = pd.merge(df, filters, how='inner', on=['user_id', 'campaign_id', 'Created'])

new_df['recency'] = pd.to_timedelta(new_df['Created'] - new_df['date'])

new_df = new_df[
    (new_df.recency <= '7 days') & 
    (new_df.recency >= '0 days')
]

# %%
cb_dfx = df_rename(cb_df)
cb_dfx = screen_surveys(cb_dfx)
cb_dfx = date_filter(cb_dfx)
#cb_dfx = cuts(cb_dfx)
#list_dfs = supporting_dfs(cb_dfx)
#final_df = combine_dfs(list_dfs)
#final_df.to_csv(save, index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-579287d8a612> in <module>()
#       1 cb_dfx = df_rename(cb_df)
#       2 cb_dfx = screen_surveys(cb_dfx)
# ----> 3 cb_dfx = date_filter(cb_dfx)
#       4 #cb_dfx = cuts(cb_dfx)
#       5 #list_dfs = supporting_dfs(cb_dfx)
#
# <ipython-input-8-425f3671fa07> in date_filter(df)
#      47     filters = df.sort_values(by=['user_id', 'campaign_id', 'Created'])
#      48     filters = df.groupby(['user_id', 'campaign_id']).first().reset_index()[['user_id', 'campaign_id', 'Created']]
# ---> 49     new_df = pd.merge(df, filters, how='inner', on=['user_id', 'campaign_id', 'Created'])
#      50
#      51     new_df['recency'] = pd.to_timedelta(new_df['Created'] - new_df['date'])
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      56                          copy=copy, indicator=indicator,
#      57                          validate=validate)
# ---> 58     return op.get_result()
#      59
#      60
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     580                 self.left, self.right)
#     581
# --> 582         join_index, left_indexer, right_indexer = self._get_join_info()
#     583
#     584         ldata, rdata = self.left._data, self.right._data
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     746         else:
#     747             (left_indexer,
# --> 748              right_indexer) = self._get_join_indexers()
#     749
#     750             if self.right_index:
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     725                                   self.right_join_keys,
#     726                                   sort=self.sort,
# --> 727                                   how=self.how)
#     728
#     729     def _get_join_info(self):
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1048
#    1049     # get left & right join labels and num. of levels at each location
# -> 1050     llab, rlab, shape = map(list, zip(* map(fkeys, left_keys, right_keys)))
#    1051
#    1052     # get flat i8 keys from label lists
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in _factorize_keys(lk, rk, sort)
#    1478     rizer = klass(max(len(lk), len(rk)))
#    1479
# -> 1480     llab = rizer.factorize(lk)
#    1481     rlab = rizer.factorize(rk)
#    1482
#
# TypeError: Argument 'values' has incorrect type (expected numpy.ndarray, got Index)

# %%
cb_dfx.head()
# Out:
#     plfh group  answer        event_time                          Created  \
# 603  VID   EXP   False  1529721705898025 2018-06-08 11:54:05.495650+00:00
# 605  VID   EXP   False  1529726713663630 2018-06-08 11:54:05.495650+00:00
# 608  BNR   EXP   False  1511624476342629 2018-06-25 16:10:31.599137+00:00
# 609  VID   EXP   False  1528710362215712 2018-06-21 17:50:08.529141+00:00
# 618  VID   EXP   False  1530161088726056 2018-06-21 17:53:23.935778+00:00
#
#      Question                                   map_dcm_creative  \
# 603       0.0  Google_Chromebook_Productivity_Offline_Asus C3...
# 605       0.0  Google_Chromebook_Productivity_Creativity Apps...
# 608       0.0             Chromebook_Pillar01_M1_AsusC101_728x90
# 609       0.0  Google_Chromebook_Productivity_Creativity Apps...
# 618       0.0  Google_Chromebook_Productivity Offline_Pixelbo...
#
#                                             map_dcm_ad  placement_id  \
# 603  Dsk_Exp1_VID-CB_DBM_Hulu_Creative-specific LPs...     223168651
# 605  Dsk_Exp1_VID-CB_DBM_Hulu_Creative-specific LPs...     223309326
# 608  Dsk_Exp2_BNR-Chromebooks_SambaTV_Chromebook Q4...     208154048
# 609  Dsk_Exp1_VID-CB_DBM_Open Exchange_Creative-spe...     221897308
# 618  Dsk_Exp1_VID-CB_DBM_Hulu_Creative-specific LPs...     223309326
#
#      campaign_id                      user_id  frequency     site  \
# 603     20920617  CAESEKfNNSTz02ILoGLnJim63dY         28     HULU
# 605     20920617  CAESEKfNNSTz02ILoGLnJim63dY         28     HULU
# 608     20334613  CAESELOXCNVdZ_qia4J1r6ZSTxU          5    SAMBA
# 609     20920617  CAESEJh6CmoyfGbv2PFgjSDUots         23  TELARIA
# 618     20920617  CAESEJHB6Tyn2vp_2FCLpJNvUw0         14     HULU
#
#     imp_table_match_creative_pixel_size  map_clicks      ad_id  rendering_id  \
# 603                                 0x0       40.24  421498570     101862590
# 605                                 0x0       98.76  421498573     101810321
# 608                              728x90       10.00  407911638      94574174
# 609                                 0x0        1.51  419871801     101870187
# 618                                 0x0      106.94  421498573     101871411
#
#     systm                             date Answer_value
# 603   MBL 2018-06-23 02:41:45.898025+00:00      MacBook
# 605   MBL 2018-06-23 04:05:13.663630+00:00      MacBook
# 608   DSK 2017-11-25 15:41:16.342629+00:00      MacBook
# 609   DSK 2018-06-11 09:46:02.215712+00:00      MacBook
# 618   MBL 2018-06-28 04:44:48.726056+00:00      MacBook

# %%
px_sql = 'SELECT * FROM Project_Abacus_Brand_Lift.Pixel_Final_noMOAT_FullScrutineer_Frequency_Flat_3_Filtered'
px_df = client.query(px_sql).to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ed28d23999bb> in <module>()
#       1 px_sql = 'SELECT * FROM Project_Abacus_Brand_Lift.Pixel_Final_noMOAT_FullScrutineer_Frequency_Flat_3_Filtered'
# ----> 2 px_df = client.query(px_sql).to_dataframe()
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\bigquery\job.py in to_dataframe(self)
#    2364             ValueError: If the `pandas` library cannot be imported.
#    2365         """
# -> 2366         return self.result().to_dataframe()
#    2367
#    2368     def __iter__(self):
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\bigquery\table.py in to_dataframe(self)
#    1034
#    1035         column_headers = [field.name for field in self.schema]
# -> 1036         rows = [row.values() for row in iter(self)]
#    1037
#    1038         return pandas.DataFrame(rows, columns=column_headers)
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\bigquery\table.py in <listcomp>(.0)
#    1034
#    1035         column_headers = [field.name for field in self.schema]
# -> 1036         rows = [row.values() for row in iter(self)]
#    1037
#    1038         return pandas.DataFrame(rows, columns=column_headers)
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\api_core\page_iterator.py in _items_iter(self)
#     197     def _items_iter(self):
#     198         """Iterator for each item returned."""
# --> 199         for page in self._page_iter(increment=False):
#     200             for item in page:
#     201                 self.num_results += 1
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\api_core\page_iterator.py in _page_iter(self, increment)
#     234                 self.num_results += page.num_items
#     235             yield page
# --> 236             page = self._next_page()
#     237
#     238     @abc.abstractmethod
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\api_core\page_iterator.py in _next_page(self)
#     347         """
#     348         if self._has_next_page():
# --> 349             response = self._get_next_page_response()
#     350             items = response.get(self._items_key, ())
#     351             page = Page(self, items, self.item_to_value)
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\bigquery\table.py in _get_next_page_response(self)
#    1003             method=self._HTTP_METHOD,
#    1004             path=self.path,
# -> 1005             query_params=params)
#    1006
#    1007     @property
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\bigquery\client.py in _call_api(self, retry, **kwargs)
#     281         if retry:
#     282             call = retry(call)
# --> 283         return call()
#     284
#     285     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     258                 sleep_generator,
#     259                 self._deadline,
# --> 260                 on_error=on_error,
#     261             )
#     262
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     175     for sleep in sleep_generator:
#     176         try:
# --> 177             return target()
#     178
#     179         # pylint: disable=broad-except
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     288         response = self._make_request(
#     289             method=method, url=url, data=data, content_type=content_type,
# --> 290             headers=headers, target_object=_target_object)
#     291
#     292         if not 200 <= response.status_code < 300:
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\_http.py in _make_request(self, method, url, data, content_type, headers, target_object)
#     181         headers['User-Agent'] = self.USER_AGENT
#     182
# --> 183         return self._do_request(method, url, headers, data, target_object)
#     184
#     185     def _do_request(self, method, url, headers, data,
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\cloud\_http.py in _do_request(self, method, url, headers, data, target_object)
#     210         """
#     211         return self.http.request(
# --> 212             url=url, method=method, headers=headers, data=data)
#     213
#     214     def api_request(self, method, path, query_params=None,
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\google\auth\transport\requests.py in request(self, method, url, data, headers, **kwargs)
#     199
#     200         response = super(AuthorizedSession, self).request(
# --> 201             method, url, data=data, headers=request_headers, **kwargs)
#     202
#     203         # If the response indicated that the credentials needed to be
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\users\william.raikes\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for df, save in zip([px_df], [px_save]):
    df = df_rename(df)
    df = screen_surveys(df)
    df = date_filter(df)
    df = cuts(df)
    list_dfs = supporting_dfs(df)
    final_df = combine_dfs(list_dfs)
    #final_df.to_csv(save, index=False)
