# %% [markdown]
# ### Last Impression Dataset

# %%
last_imp = df.sort_values(by=['user_id', 
                              'campaign_id', 
                              'date'], ascending=[True, True, False]).groupby(['user_id', 
                                                                               'campaign_id']).first().reset_index()

# %%
last_imp.head()
# Out:
#                         user_id  campaign_id    plfh group        event_time  \
# 0   CAESEA075WX-Zar5QV3wMC3-ZDc     20334613     BNR   EXP  1514410697967032
# 1   CAESEA0eyv8LxeuFLIxgfYjTM0w     20920617     VID   EXP  1529556865833311
# 2   CAESEA0scZsis0RkaAPWK1_75-Y     20334613     BNR   CON  1514218595802957
# 3   CAESEA15rhYSfY5NAmv8c7_k9rs     20920617     BNR   CON  1529961612946707
# 4   CAESEA1ReHnNfeAU8RAiwK8LpXI     20334613  HGHIMP   EXP  1511711998254282
# 5   CAESEA1VTVc1fS-1RK0aN30q118     20334613     BNR   CON  1510031192698842
# 6   CAESEA1nVtaH7ruFD7LtZzxoisw     20570795     BNR   EXP  1521385192200691
# 7   CAESEA30wnq9VDKjDVRtz22yZcg     20334613     BNR   CON  1514380979074818
# 8   CAESEA3EoLew0uGCHJ8TWdRC4Vs     20334613     BNR   CON  1510462620202313
# 9   CAESEA3hUB17LbzS-iFnp-ErcK8     20334613     BNR   EXP  1514468627399971
# 10  CAESEA5CNE1oEvisRpeuktRz6U0     20334613     BNR   CON  1510538264279527
# ...

# %%
last_imp.shape
# Out:
# (2791, 33)

# %%
last_imp.to_csv(r'C:\Users\william.raikes\Programming\Python\abacus\v1_model\data\clean\explanatory\cb_last_imp.csv')
